# %%
import sys
import os

# Get the path to the current working directory
current_dir = os.getcwd()

# Get the path to the parent directory (containing both A.py and 'B' directory)
parent_dir = os.path.dirname(current_dir)

london_data_dir = os.path.join(parent_dir, 'Data/Irish_dataset/preprocessed')
results_dir = os.path.join(current_dir, 'resultsIreland')
# Append the parent directory to the module search path
sys.path.append(parent_dir)

import pickle 
from sklearn.tree import DecisionTreeRegressor, export_text
from scengen.generators import PredClusGenerator, SampleGenerator, RandomGenerator
from sklearn import tree
import pandas as pd
import graphviz


with open(os.path.join(results_dir,"notebooks/resultsIreland/ThesisResults/PCT_D8_M250_london_dataset_with_buffer_feb_0.pkl"), 'rb') as file:
    loaded_model = pickle.load(file)
time_df = pd.read_pickle("notebooks/visualisationresults/t_buffer_feb_ireland.pkl")
attributes_df = pd.read_pickle("notebooks/visualisationresults/a_buffer_feb_ireland.pkl")
vistree = loaded_model.to_visualization_tree(attributes_df, time_df)

# %%
import pandas as pd

# Assuming 'X_train' is your training DataFrame and 'model' is your trained DecisionTreeRegressor
feature_names = attributes_df.columns
importances = loaded_model.tree.feature_importances_

# Create a dictionary mapping feature names to their importances
feature_importance_dict = dict(zip(feature_names, importances))

# Alternatively, create a sorted list of tuples for better visualization
sorted_feature_importances = sorted(zip(feature_names, importances), key=lambda x: x[1], reverse=True)

# You can print or view the sorted feature importances
for feature, importance in sorted_feature_importances:
    print(f"Feature: {feature}, Importance: {importance}")
# Out:
# Feature: yearly_consumption, Importance: 0.7541079797018329
# Feature: sameseason, Importance: 0.049983948311017365
# Feature: sunHour, Importance: 0.024148970993577795
# Feature: night_total_consumption, Importance: 0.021632754598692884
# Feature: evening_total_consumption, Importance: 0.016857287631658488
# Feature: dayOfWeek, Importance: 0.014792628838331146
# Feature: lunch_total_consumption_weekday, Importance: 0.013216827386963635
# Feature: season, Importance: 0.009337455906949422
# Feature: night_total_consumption_weekday, Importance: 0.009115376917309377
# Feature: total_consumption_buffer, Importance: 0.008158790962924857
# Feature: isWeekend, Importance: 0.006514189975043054
# Feature: morning_total_consumption, Importance: 0.006365018842571348
# Feature: lunch_total_consumption, Importance: 0.0059820034388313684
# Feature: morning_total_consumption_weekday, Importance: 0.0056458128701835095
# Feature: night_peak, Importance: 0.005619149536394701
# Feature: feelsLikeC, Importance: 0.005405931831943012
# Feature: TimeFromBuffer, Importance: 0.004684177262775304
# Feature: evening_total_consumption_weekday, Importance: 0.004155051635308465
# Feature: age, Importance: 0.003365088874285917
# Feature: lunch_peak, Importance: 0.002711808012985616
# Feature: embedding_dist, Importance: 0.0026260138751475065
# Feature: avgTempC, Importance: 0.0023864023376880257
# Feature: morning_total_consumption_weekend, Importance: 0.0018340022984508766
# Feature: lunch_total_consumption_weekend, Importance: 0.0017782566208396169
# Feature: dayOfYear, Importance: 0.001720456949882715
# Feature: lunch_peak_weekday, Importance: 0.0015761615910028176
# Feature: evening_total_consumption_weekend, Importance: 0.0015690642810970794
# Feature: minTempC, Importance: 0.0014333043704662068
# Feature: total_consumption_buffer_weekday, Importance: 0.0012990607144402508
# Feature: transition_matrix, Importance: 0.0010966109948261668
# Feature: morning_peak_weekday, Importance: 0.0010711364352361031
# Feature: morning_peak, Importance: 0.0010580674234818498
# Feature: median_weekday, Importance: 0.0009836177304644836
# Feature: night_peak_weekday, Importance: 0.0007806131018818081
# Feature: entropy_pairs, Importance: 0.000777749964988463
# Feature: stretch_high, Importance: 0.0005973182150739972
# Feature: std_weekday, Importance: 0.0005626934739719901
# Feature: acf_first_min, Importance: 0.0005523077886277078
# Feature: average, Importance: 0.0005015005757017997
# Feature: night_peak_weekend, Importance: 0.0004813661881728722
# Feature: high_fluctuation, Importance: 0.00044626823175033674
# Feature: skewness, Importance: 0.000386815960268321
# Feature: average_weekend, Importance: 0.0003772172841294514
# Feature: ami_timescale, Importance: 0.00032213753413132485
# Feature: whiten_timescale, Importance: 0.0002888963099909862
# Feature: median, Importance: 0.00024030756552931827
# Feature: median_weekend, Importance: 0.0002170163453407873
# Feature: floor_area, Importance: 0.00021627066973020618
# Feature: ami2, Importance: 0.00020513831179551684
# Feature: std_weekend, Importance: 0.0001621803733305658
# Feature: centroid_freq, Importance: 0.0001477322536636858
# Feature: heating_solid_fuel, Importance: 0.00014751504214915951
# Feature: average_weekday, Importance: 0.00014019535264595703
# Feature: dfa, Importance: 6.550770386493016e-05
# Feature: build_year, Importance: 5.883336855371545e-05
# Feature: highest_weekday, Importance: 5.683265718055422e-05
# Feature: highest, Importance: 3.517657492279934e-05
# Feature: maxTempC, Importance: 0.0
# Feature: uvIndex, Importance: 0.0
# Feature: windspeedKmph, Importance: 0.0
# Feature: humidity, Importance: 0.0
# Feature: dayOfMonth, Importance: 0.0
# Feature: month, Importance: 0.0
# Feature: year, Importance: 0.0
# Feature: isHoliday, Importance: 0.0
# Feature: number_of_adults, Importance: 0.0
# Feature: number_of_children, Importance: 0.0
# Feature: home_age, Importance: 0.0
# Feature: number_of_bedrooms, Importance: 0.0
# Feature: heating_elec_central, Importance: 0.0
# Feature: heating_elec_plugin, Importance: 0.0
# Feature: heating_gas, Importance: 0.0
# Feature: heating_oil, Importance: 0.0
# Feature: heating_renewable, Importance: 0.0
# Feature: heating_other, Importance: 0.0
# Feature: waterheating_central, Importance: 0.0
# Feature: waterheating_elec_immersion, Importance: 0.0
# Feature: waterheating_elec_instant, Importance: 0.0
# Feature: waterheating_gas, Importance: 0.0
# Feature: waterheating_oil, Importance: 0.0
# Feature: waterheating_solid, Importance: 0.0
# Feature: waterheating_renewable, Importance: 0.0
# Feature: waterheating_other, Importance: 0.0
# Feature: home_type_Apartment, Importance: 0.0
# Feature: home_type_Bungalow, Importance: 0.0
# Feature: home_type_Detached, Importance: 0.0
# Feature: home_type_Semi-detached, Importance: 0.0
# Feature: home_type_Terraced, Importance: 0.0
# Feature: home_type_Unknown, Importance: 0.0
# Feature: cooking_Electric, Importance: 0.0
# Feature: cooking_Gas, Importance: 0.0
# Feature: cooking_Oil, Importance: 0.0
# Feature: cooking_Solid, Importance: 0.0
# Feature: evening_peak, Importance: 0.0
# Feature: kurtosis, Importance: 0.0
# Feature: min, Importance: 0.0
# Feature: std, Importance: 0.0
# Feature: evening_peak_weekday, Importance: 0.0
# Feature: kurtosis_weekday, Importance: 0.0
# Feature: min_weekday, Importance: 0.0
# Feature: skewness_weekday, Importance: 0.0
# Feature: evening_peak_weekend, Importance: 0.0
# Feature: highest_weekend, Importance: 0.0
# Feature: lunch_peak_weekend, Importance: 0.0
# Feature: min_weekend, Importance: 0.0
# Feature: morning_peak_weekend, Importance: 0.0
# Feature: night_total_consumption_weekend, Importance: 0.0
# Feature: total_consumption_buffer_weekend, Importance: 0.0
# Feature: mode_5, Importance: 0.0
# Feature: mode_10, Importance: 0.0
# Feature: acf_timescale, Importance: 0.0
# Feature: trev, Importance: 0.0
# Feature: periodicity, Importance: 0.0
# Feature: outlier_timing_pos, Importance: 0.0
# Feature: outlier_timing_neg, Importance: 0.0
# Feature: stretch_decreasing, Importance: 0.0
# Feature: rs_range, Importance: 0.0
# Feature: low_freq_power, Importance: 0.0
# Feature: forecast_error, Importance: 0.0

# %%
from data_preprocessing.get_buffer_attributes import BufferAttributesCalculator
calculator = BufferAttributesCalculator(None)
column_names = list(calculator.column_functions.keys())
columns_weekday = [f"{column}_weekday" for column in column_names]
columns_weekend = [f"{column}_weekend" for column in column_names]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

base_color = '#1D8DB0'
palette = sns.light_palette(base_color, n_colors=15)

# Assuming 'X_train' is your training DataFrame and 'model' is your trained DecisionTreeRegressor
feature_names = attributes_df.columns
importances = loaded_model.tree.feature_importances_

# Create a sorted list of tuples for better visualization
sorted_feature_importances = sorted(zip(feature_names, importances), key=lambda x: x[1], reverse=True)

# Extract top 15 features and their importances
top_features = [x[0] for x in sorted_feature_importances[:15]]
top_importances = [x[1] for x in sorted_feature_importances[:15]]

total_importance_percentage = sum(top_importances) * 100
# List of special features

# Plotting
plt.figure(figsize=(10, 6))
for feature, importance in zip(top_features, top_importances):
    color = palette[3]
    weight = 'normal'
    if feature in special_attributes or feature == "sameseason":
        color = palette[14]
        weight = 'bold'
    plt.barh(feature, importance, color=color, alpha=0.6)
    plt.text(importance, feature, f' {importance:.2%}', ha='left', va='center', weight=weight)
plt.xscale('log')  # Set x-axis scale to logarithmic
plt.xlabel('Importance in %')
plt.ylabel('Attribute')
plt.title(f'Top 15 Attribute Importances (Log Scale) (Total Percentage = {total_importance_percentage:.2f}%)')
plt.gca().invert_yaxis()  # Invert y-axis to have the most important feature at the top
plt.savefig('notebooks/pictures/featureimportancesIreland.png', bbox_inches='tight', dpi=300, transparent=True)
plt.show()
print(f'Total importance percentage covered by top 15 features: {total_importance_percentage:.2f}%')
# Out:
# Total importance percentage covered by top 15 features: 95.15%

# %%
from data_preprocessing.get_buffer_attributes import BufferAttributesCalculator
calculator = BufferAttributesCalculator(None)
column_names = list(calculator.column_functions.keys())
columns_weekday = [f"{column}_weekday" for column in column_names]
columns_weekend = [f"{column}_weekend" for column in column_names]

# %%
import pandas as pd

# Assuming 'X_train' is your training DataFrame and 'model' is your trained DecisionTreeRegressor
feature_names = attributes_df.columns
importances = loaded_model.tree.feature_importances_

# Create a dictionary mapping feature names to their importances
feature_importance_dict = dict(zip(feature_names, importances))

# Alternatively, create a sorted list of tuples for better visualization
sorted_feature_importances = sorted(zip(feature_names, importances), key=lambda x: x[1], reverse=True)

# You can print or view the sorted feature importances
for feature, importance in sorted_feature_importances:
    print(f"Feature: {feature}, Importance: {importance}")
# Out:
# Feature: yearly_consumption, Importance: 0.7541079797018329
# Feature: sameseason, Importance: 0.049983948311017365
# Feature: sunHour, Importance: 0.024148970993577795
# Feature: night_total_consumption, Importance: 0.021632754598692884
# Feature: evening_total_consumption, Importance: 0.016857287631658488
# Feature: dayOfWeek, Importance: 0.014792628838331146
# Feature: lunch_total_consumption_weekday, Importance: 0.013216827386963635
# Feature: season, Importance: 0.009337455906949422
# Feature: night_total_consumption_weekday, Importance: 0.009115376917309377
# Feature: total_consumption_buffer, Importance: 0.008158790962924857
# Feature: isWeekend, Importance: 0.006514189975043054
# Feature: morning_total_consumption, Importance: 0.006365018842571348
# Feature: lunch_total_consumption, Importance: 0.0059820034388313684
# Feature: morning_total_consumption_weekday, Importance: 0.0056458128701835095
# Feature: night_peak, Importance: 0.005619149536394701
# Feature: feelsLikeC, Importance: 0.005405931831943012
# Feature: TimeFromBuffer, Importance: 0.004684177262775304
# Feature: evening_total_consumption_weekday, Importance: 0.004155051635308465
# Feature: age, Importance: 0.003365088874285917
# Feature: lunch_peak, Importance: 0.002711808012985616
# Feature: embedding_dist, Importance: 0.0026260138751475065
# Feature: avgTempC, Importance: 0.0023864023376880257
# Feature: morning_total_consumption_weekend, Importance: 0.0018340022984508766
# Feature: lunch_total_consumption_weekend, Importance: 0.0017782566208396169
# Feature: dayOfYear, Importance: 0.001720456949882715
# Feature: lunch_peak_weekday, Importance: 0.0015761615910028176
# Feature: evening_total_consumption_weekend, Importance: 0.0015690642810970794
# Feature: minTempC, Importance: 0.0014333043704662068
# Feature: total_consumption_buffer_weekday, Importance: 0.0012990607144402508
# Feature: transition_matrix, Importance: 0.0010966109948261668
# Feature: morning_peak_weekday, Importance: 0.0010711364352361031
# Feature: morning_peak, Importance: 0.0010580674234818498
# Feature: median_weekday, Importance: 0.0009836177304644836
# Feature: night_peak_weekday, Importance: 0.0007806131018818081
# Feature: entropy_pairs, Importance: 0.000777749964988463
# Feature: stretch_high, Importance: 0.0005973182150739972
# Feature: std_weekday, Importance: 0.0005626934739719901
# Feature: acf_first_min, Importance: 0.0005523077886277078
# Feature: average, Importance: 0.0005015005757017997
# Feature: night_peak_weekend, Importance: 0.0004813661881728722
# Feature: high_fluctuation, Importance: 0.00044626823175033674
# Feature: skewness, Importance: 0.000386815960268321
# Feature: average_weekend, Importance: 0.0003772172841294514
# Feature: ami_timescale, Importance: 0.00032213753413132485
# Feature: whiten_timescale, Importance: 0.0002888963099909862
# Feature: median, Importance: 0.00024030756552931827
# Feature: median_weekend, Importance: 0.0002170163453407873
# Feature: floor_area, Importance: 0.00021627066973020618
# Feature: ami2, Importance: 0.00020513831179551684
# Feature: std_weekend, Importance: 0.0001621803733305658
# Feature: centroid_freq, Importance: 0.0001477322536636858
# Feature: heating_solid_fuel, Importance: 0.00014751504214915951
# Feature: average_weekday, Importance: 0.00014019535264595703
# Feature: dfa, Importance: 6.550770386493016e-05
# Feature: build_year, Importance: 5.883336855371545e-05
# Feature: highest_weekday, Importance: 5.683265718055422e-05
# Feature: highest, Importance: 3.517657492279934e-05
# Feature: maxTempC, Importance: 0.0
# Feature: uvIndex, Importance: 0.0
# Feature: windspeedKmph, Importance: 0.0
# Feature: humidity, Importance: 0.0
# Feature: dayOfMonth, Importance: 0.0
# Feature: month, Importance: 0.0
# Feature: year, Importance: 0.0
# Feature: isHoliday, Importance: 0.0
# Feature: number_of_adults, Importance: 0.0
# Feature: number_of_children, Importance: 0.0
# Feature: home_age, Importance: 0.0
# Feature: number_of_bedrooms, Importance: 0.0
# Feature: heating_elec_central, Importance: 0.0
# Feature: heating_elec_plugin, Importance: 0.0
# Feature: heating_gas, Importance: 0.0
# Feature: heating_oil, Importance: 0.0
# Feature: heating_renewable, Importance: 0.0
# Feature: heating_other, Importance: 0.0
# Feature: waterheating_central, Importance: 0.0
# Feature: waterheating_elec_immersion, Importance: 0.0
# Feature: waterheating_elec_instant, Importance: 0.0
# Feature: waterheating_gas, Importance: 0.0
# Feature: waterheating_oil, Importance: 0.0
# Feature: waterheating_solid, Importance: 0.0
# Feature: waterheating_renewable, Importance: 0.0
# Feature: waterheating_other, Importance: 0.0
# Feature: home_type_Apartment, Importance: 0.0
# Feature: home_type_Bungalow, Importance: 0.0
# Feature: home_type_Detached, Importance: 0.0
# Feature: home_type_Semi-detached, Importance: 0.0
# Feature: home_type_Terraced, Importance: 0.0
# Feature: home_type_Unknown, Importance: 0.0
# Feature: cooking_Electric, Importance: 0.0
# Feature: cooking_Gas, Importance: 0.0
# Feature: cooking_Oil, Importance: 0.0
# Feature: cooking_Solid, Importance: 0.0
# Feature: evening_peak, Importance: 0.0
# Feature: kurtosis, Importance: 0.0
# Feature: min, Importance: 0.0
# Feature: std, Importance: 0.0
# Feature: evening_peak_weekday, Importance: 0.0
# Feature: kurtosis_weekday, Importance: 0.0
# Feature: min_weekday, Importance: 0.0
# Feature: skewness_weekday, Importance: 0.0
# Feature: evening_peak_weekend, Importance: 0.0
# Feature: highest_weekend, Importance: 0.0
# Feature: lunch_peak_weekend, Importance: 0.0
# Feature: min_weekend, Importance: 0.0
# Feature: morning_peak_weekend, Importance: 0.0
# Feature: night_total_consumption_weekend, Importance: 0.0
# Feature: total_consumption_buffer_weekend, Importance: 0.0
# Feature: mode_5, Importance: 0.0
# Feature: mode_10, Importance: 0.0
# Feature: acf_timescale, Importance: 0.0
# Feature: trev, Importance: 0.0
# Feature: periodicity, Importance: 0.0
# Feature: outlier_timing_pos, Importance: 0.0
# Feature: outlier_timing_neg, Importance: 0.0
# Feature: stretch_decreasing, Importance: 0.0
# Feature: rs_range, Importance: 0.0
# Feature: low_freq_power, Importance: 0.0
# Feature: forecast_error, Importance: 0.0

# %%
import pandas as pd

# Assuming 'X_train' is your training DataFrame and 'model' is your trained DecisionTreeRegressor
feature_names = attributes_df.columns
importances = loaded_model.tree.feature_importances_

# Create a sorted list of tuples for better visualization
sorted_feature_importances = sorted(zip(feature_names, importances), key=lambda x: x[1], reverse=True)

# Print the top 15 feature importances in a visually appealing format
print("Top 15 Feature Importances:")
print("---------------------------")
for rank, (feature, importance) in enumerate(sorted_feature_importances[:15], start=1):
    print(f"{rank}. {feature}: {importance:.4f}")
# Out:
# Top 15 Feature Importances:
# ---------------------------
# 1. yearly_consumption: 0.7541
# 2. sameseason: 0.0500
# 3. sunHour: 0.0241
# 4. night_total_consumption: 0.0216
# 5. evening_total_consumption: 0.0169
# 6. dayOfWeek: 0.0148
# 7. lunch_total_consumption_weekday: 0.0132
# 8. season: 0.0093
# 9. night_total_consumption_weekday: 0.0091
# 10. total_consumption_buffer: 0.0082
# 11. isWeekend: 0.0065
# 12. morning_total_consumption: 0.0064
# 13. lunch_total_consumption: 0.0060
# 14. morning_total_consumption_weekday: 0.0056
# 15. night_peak: 0.0056

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'X_train' is your training DataFrame and 'model' is your trained DecisionTreeRegressor
feature_names = attributes_df.columns
importances = loaded_model.tree.feature_importances_

# Create a sorted list of tuples for better visualization
sorted_feature_importances = sorted(zip(feature_names, importances), key=lambda x: x[1], reverse=True)

# Extract top 15 features and their importances
top_features = [x[0] for x in sorted_feature_importances[:15]]
top_importances = [x[1] for x in sorted_feature_importances[:15]]

# Plotting
plt.figure(figsize=(10, 6))
plt.barh(top_features, top_importances, color='skyblue')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Top 15 Feature Importances')
plt.gca().invert_yaxis()  # Invert y-axis to have the most important feature at the top
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'X_train' is your training DataFrame and 'model' is your trained DecisionTreeRegressor
feature_names = attributes_df.columns
importances = loaded_model.tree.feature_importances_

# Create a sorted list of tuples for better visualization
sorted_feature_importances = sorted(zip(feature_names, importances), key=lambda x: x[1], reverse=True)

# Extract top 15 features and their importances
top_features = [x[0] for x in sorted_feature_importances[:15]]
top_importances = [x[1] for x in sorted_feature_importances[:15]]

# Plotting
plt.figure(figsize=(10, 6))
plt.barh(top_features, top_importances, color='skyblue')
plt.xscale('log')  # Set x-axis scale to logarithmic
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Top 15 Feature Importances (Log Scale)')
plt.gca().invert_yaxis()  # Invert y-axis to have the most important feature at the top
plt.show()

# %%
import pygraphviz as pgv
from io import StringIO

# DOT data stored in a variable
dot_data = tree.export_graphviz(loaded_model.tree, out_file=None, feature_names=attributes_df.columns.tolist(), filled=True, rounded=True)

# Convert DOT data to a file-like object
dot_file_object = StringIO(dot_data)

# Load DOT data
graph = pgv.AGraph(string=dot_file_object.read())

# List of special attributes
special_attributes = column_names + columns_weekday + columns_weekend

# Function to check if a node label contains a special attribute
def has_special_attribute(label):
    return any(attr in label for attr in special_attributes)
def has_time_attribute(label):
    return any(attr in label for attr in ["TimeFromBuffer"])

# Iterate through nodes and color nodes with special attributes
used_special_attributes = []
for node in graph.nodes():
    if has_special_attribute(node.attr['label']):
        node.attr['fillcolor'] = 'blue'
        special_attributes.append(node.attr['label'])
# for node in graph.nodes():
#     if has_time_attribute(node.attr['label']):
#         node.attr['fillcolor'] = 'green'

# Save the modified DOT file
output_dot_data = graph.to_string()
# Now you can use the modified DOT data as needed

# %%
# Visualize the decision tree using Graphviz
graph = graphviz.Source(output_dot_data)
graph.render("decision_tree", format="pdf", cleanup=True, view=True)
graph.view("decision_tree")
# Out:
# 'decision_tree.pdf'
